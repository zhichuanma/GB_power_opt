# %%
from __future__ import division
import pandas as pd
import numpy as np
import random
import time
import re
from coopr.pyomo import *
#from pyomo.environ import *
from pyomo.opt import SolverFactory
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.rcParams['mathtext.default'] = 'regular'

# %% [markdown]
# # Data Input

# %%
charging_rate = 1
n_ev = 100
ev_scale = 5567.33
# ----- data inputs -------
net_power = pd.read_excel('GB_System.xlsx', sheet_name=None)
n_time = 48
n_bus = 14
n_line = 22
n_dem = 14
n_cs = 14
n_dg = 39
n_res = 12
carbon_price = 52.56/1e6 # £/g
delt = 0.5
# --------- 14 buses, 22 lines, 44 generators ----------
# power network
Power_line = net_power['line']['Line_ID'].values
Line_top = pd.read_excel('GB_System.xlsx', 'line', usecols=[1,2]).values
Line_cap = net_power['line']['cap'].values
Line_xl = net_power['line']['xl'].values
Xbase = 0.0005
slack = 0 # reference bus
# demand
Dem_bus = net_power['dem']['Bus_ID'].values
Dem_base = net_power['dem']['base'].values
Dem_unit = net_power['dem'].values[:,-n_time:]
# wind and solar
RES_bus = net_power['res']['Bus_ID'].values
RES_base = net_power['res']['base'].values
RES_unit = net_power['res'].values[:,-n_time:]
# generator
DG_bus = net_power['dg']['Bus_ID'].values
DG_type = net_power['dg']['Type'].values
DG_Pmax = net_power['dg']['Pmax'].values
DG_lambda = net_power['dg']['lambdaG'].values
DG_Carbon = net_power['dg']['Carbon'].values
# charging station
CS_bus = net_power['cs']['Bus_ID'].values
CS_ev = net_power['cs']['base'].values * n_ev
SetCSI = []
for k in range(n_cs): 
    if k == 0:
        first_value = 0
        second_value = int(CS_ev[k])
        SetCSI.append(range(first_value, second_value))
    else:
        first_value = int(sum(CS_ev[:k]))
        second_value = first_value + int(CS_ev[k])
        SetCSI.append(range(first_value, second_value))
# EV
EV_Ptrl = (1.8/1000) * ev_scale #1.8
EV_Pmax = net_power['ev']['Pmax'].values[0]/1000 * ev_scale
EV_Emax = net_power['ev']['Emax'].values[0]/1000 * ev_scale
EV_Effi = net_power['ev']['Effi'].values[0]
EV_SoC = net_power['ev']['SoC'].values[0]
# ev transport info
ev_time_leave_home = net_power['travel']['time_leave_home'].values[0]
ev_time_arrive_office = net_power['travel']['time_arrive_office'].values[0]
ev_time_leave_office = net_power['travel']['time_leave_office'].values[0]
ev_time_arrive_home = net_power['travel']['time_arrive_home'].values[0]
# compute grid-on and grid-off binary ev
ev_A = np.zeros([n_ev,n_time])
np.random.seed(seed=0)
random_time = 2
for i in range(n_ev):
    time_leave_home = round(np.random.uniform(-random_time,random_time))
    time_arrive_office = round(np.random.uniform(-random_time,random_time))
    time_leave_office = round(np.random.uniform(-random_time,random_time))
    time_arrive_home = round(np.random.uniform(-random_time,random_time))
    for t in range(n_time):
        if t < ev_time_leave_home + time_leave_home or t > ev_time_arrive_home + time_arrive_home:
            ev_A[i,t] = 1
        if t > ev_time_arrive_office + time_arrive_office and t < ev_time_leave_office + time_leave_office:
            ev_A[i,t] = 1
        if t >= ev_time_leave_home + time_leave_home and t <= ev_time_arrive_office + time_arrive_office:
            ev_A[i,t] = 0
        if t >= ev_time_leave_office + time_leave_office and t <= ev_time_arrive_home + time_arrive_home:
            ev_A[i,t] = 0

# %% [markdown]
# # Carbon Intensity

# %%
def calculate_carbon_intensity(time, dg_sol, res_sol, ev_discharge, flow_sol):
    
    Gen_Bus = np.concatenate((DG_bus, RES_bus, CS_bus), axis=0)
    Gen_Day = np.vstack((dg_sol, res_sol, -ev_discharge)).T
    RES_Carbon = np.zeros(n_res)
    EV_Carbon = np.zeros(n_cs)
    Gen_CF = np.concatenate((DG_Carbon, RES_Carbon, EV_Carbon), axis=0)

    # define terms
    P_CEFG = np.zeros([n_bus, n_dg+n_res+n_cs])
    e_CEFG = Gen_CF
    P_B = np.zeros([n_bus, n_bus])
    
    # calculate power generation for each bus
    Gen_t = Gen_Day[time]
    for b in range(n_bus):
        for g in range(len(Gen_Bus)):
            if b == Gen_Bus[g]:
                P_CEFG[b,g] = Gen_t[g]
            
    # calculate power flow
    for l in range(n_line):
        b = Line_top[l,0]
        p = Line_top[l,1]
        if flow_sol[l,time] >= 0:
            P_B[b,p] = flow_sol[l,time]
        else:
            P_B[p,b] = - flow_sol[l,time]
            
    # calculate carbon emission rates of power genenration
    r_CEFG = P_CEFG.dot(e_CEFG)
    
    # calculate the distribution of power inflows from both other buses and local generators 
    P_CEFT = np.diag( np.ones([1, n_bus+len(Gen_Bus)]).dot(np.vstack((P_B, P_CEFG.transpose())))[0] )
    
    # calculate bus carbon emission intensities
    e_CEFT = np.linalg.pinv(P_CEFT - P_B.transpose()).dot(r_CEFG)
    
    return e_CEFT

# %% [markdown]
# # Stage 1: National Grid

# %%
def national_grid(ev_sol):

    model = ConcreteModel()
    model.dual = Suffix(direction=Suffix.IMPORT)

    model.T = Set(initialize=range(n_time))
    model.I = Set(initialize=range(n_ev))
    model.K = Set(initialize=range(n_cs))
    model.B = Set(initialize=range(n_bus))
    model.L = Set(initialize=range(n_line))
    model.Dem = Set(initialize=range(n_dem))
    model.DG = Set(initialize=range(n_dg))
    model.RES = Set(initialize=range(n_res))

    model.dg = Var(model.DG, model.T, within=NonNegativeReals) # power dispatch of dg g
    model.res = Var(model.RES, model.T, within=NonNegativeReals) # power dispatch of pv g
    model.theta = Var(model.B, model.T, bounds=(-3.1415926,3.1415926)) # nodal voltage
    model.GenCost = Var(within=NonNegativeReals)
    model.GenCarbon = Var(within=NonNegativeReals)

    # compute the set of buses of connected to bus b
    def node_set_rule(model, b):
        node = []
        for l in model.L:
            if Line_top[l,0] == b:
                node.append(Line_top[l,1]) 
            elif Line_top[l,1] == b:
                node.append(Line_top[l,0])
        return node
    model.Phi = Set(model.B, initialize=node_set_rule)

    # compute the reactance of line connected node p and b
    def line_reactance_rule(model, b, p):
        for l in model.L:
            if Line_top[l,0] == b and Line_top[l,1] == p:
                return Line_xl[l]*Xbase
            elif Line_top[l,1] == b and Line_top[l,0] == p: 
                return Line_xl[l]*Xbase
    model.line_rc = Param(model.B, model.B, rule=line_reactance_rule)

    # maximum generation output limit
    def maximum_gen_output_rule(model, i, t):
        return model.dg[i,t] <= DG_Pmax[i]
    model.MaxGenOutputRule = Constraint(model.DG, model.T, rule=maximum_gen_output_rule)

    # res curtailment
    def maximum_res_output_rule(model, i, t):
        return model.res[i,t] <= RES_unit[i,t]
    model.MaxRESOutputRule = Constraint(model.RES, model.T, rule=maximum_res_output_rule)

    # demand-supply balance at each bus
    def power_demand_supply_balance_rule(model, b, t):
        return + sum(Dem_unit[d,t] for d in model.Dem if Dem_bus[d] == b) \
               + sum(ev_sol[k,t] for k in model.K if CS_bus[k] == b) \
               - sum(model.dg[g,t] for g in model.DG if DG_bus[g] == b) \
               - sum(model.res[g,t] for g in model.RES if RES_bus[g] == b) \
               + sum((model.theta[b,t]-model.theta[p,t])/model.line_rc[b,p] for p in model.Phi[b]) == 0 
    model.DemandSupplyBalanceRule = Constraint(model.B, model.T, rule=power_demand_supply_balance_rule)

    # power network constraints
    def power_flow_capacity_rule1(model, l, t):
        return (model.theta[Line_top[l,0],t] - model.theta[Line_top[l,1],t])/(Line_xl[l] * Xbase) <= Line_cap[l]
    model.PowerFlowCapacity1 = Constraint(model.L, model.T, rule=power_flow_capacity_rule1)

    def power_flow_capacity_rule2(model, l, t):
        return (model.theta[Line_top[l,0],t] - model.theta[Line_top[l,1],t])/(Line_xl[l] * Xbase) >= - Line_cap[l]
    model.PowerFlowCapacity2 = Constraint(model.L, model.T, rule=power_flow_capacity_rule2)

    def reference_angle_rule(model, t):
        return model.theta[slack, t] == 0
    model.ReferenceAngle = Constraint(model.T, rule=reference_angle_rule)

    # cost minimization
    def _power_cost_(model):
        return model.GenCost == sum( DG_lambda[g] * model.dg[g,t] for g in model.DG for t in model.T )
    model.ComputeGenCost = Constraint(rule=_power_cost_)

    def _power_carbon_(model):
        return model.GenCarbon == sum( carbon_price * DG_Carbon[g] * model.dg[g,t] * 1000 for g in model.DG for t in model.T )
    model.ComputeGenCarbon = Constraint(rule=_power_carbon_)

    # -------------------------- Objective function -------------------------------
    def _obj_(model):
        return model.GenCost + model.GenCarbon
    model.objective = Objective(rule=_obj_, sense=minimize)

    #--------------------------- Run Optimization ---------------------------------     
    instance = model.create_instance()
    solver = SolverFactory('gurobi')
    results = solver.solve(instance, tee=False)
    #print(results)

    #----------------- Collect power solutions ---------------------- 
    dg_sol = np.zeros([n_dg,n_time]) 
    res_sol = np.zeros([n_res,n_time]) 
    angle_sol = np.zeros([n_bus,n_time])
    flow_sol = np.zeros([n_line,n_time])

    for t in instance.T:
        for g in instance.DG:
            dg_sol[g,t] = instance.dg[g,t].value
        for g in instance.RES:
            res_sol[g,t] = instance.res[g,t].value
        for b in instance.B:
            angle_sol[b,t] = instance.theta[b,t].value

    for l in instance.L:
        for t in instance.T:
            flow_sol[l,t] = (angle_sol[Line_top[l,0],t] - angle_sol[Line_top[l,1],t])/(Line_xl[l] * Xbase)
    
    return dg_sol, res_sol, flow_sol, instance.GenCost.value, instance.GenCarbon.value

# %% [markdown]
# # Stage 2: V2G Response

# %%
def v2g_response(cs_no, Bus_CI):
    
    model = ConcreteModel()
    model.dual = Suffix(direction=Suffix.IMPORT)

    model.T = Set(initialize=range(n_time))
    model.I = Set(initialize=range(n_ev))

    model.ev_c = Var(model.I, model.T, within=NonNegativeReals)
    model.ev_d = Var(model.I, model.T, within=NonNegativeReals)
    model.ev_e = Var(model.I, model.T, within=NonNegativeReals)
    model.ev_u = Var(model.I, model.T, within=Binary)
    model.cs_pow = Var(model.T, within=Reals)
    model.V2GRevenue = Var(within=NonNegativeReals)

    # ev charge
    def _ev_charge_rule(model, i, t):
        return model.ev_c[i,t] <= EV_Pmax * model.ev_u[i,t] * ev_A[i,t] * charging_rate
    model.EVChargeRule = Constraint(model.I, model.T, rule=_ev_charge_rule)

    # ev discharge
    def _ev_discharge_road_rule(model, i, t): 
        if ev_A[i,t] == 0:
            return model.ev_d[i,t] == EV_Ptrl * charging_rate
        else:
            return model.ev_d[i,t] <= EV_Pmax * (1 - model.ev_u[i,t]) * ev_A[i,t] * charging_rate
    model.EVDisChargeRoadRule = Constraint(model.I, model.T, rule=_ev_discharge_road_rule)

    # ev energy capacity
    def _ev_capacity_rule(model, i, t):
        return model.ev_e[i,t] <= EV_Emax
    model.EVCapacity = Constraint(model.I, model.T, rule=_ev_capacity_rule)

    # ev energy content
    def _ev_soc_rule(model, i, t):
        if t == model.T.first():
            return model.ev_e[i,t] == EV_SoC*EV_Emax + model.ev_c[i,t]*EV_Effi*delt - model.ev_d[i,t]*delt/EV_Effi
        else:
            return model.ev_e[i,t] == model.ev_e[i,t-1] + model.ev_c[i,t]*EV_Effi*delt - model.ev_d[i,t]*delt/EV_Effi
    model.EVSoC = Constraint(model.I, model.T, rule=_ev_soc_rule)

    # cs power 
    def _cs_power_rule(model, t):
        return model.cs_pow[t] == sum( (model.ev_c[i,t]-model.ev_d[i,t])*ev_A[i,t] for i in SetCSI[cs_no] )
    model.CSPower = Constraint(model.T, rule=_cs_power_rule)

    # revenue maximization
    def _v2g_revenue_(model):
        return model.V2GRevenue == -sum( carbon_price * Bus_CI.T[cs_no,t] * model.cs_pow[t] for t in model.T )
    model.ComputeV2GRevenue = Constraint(rule=_v2g_revenue_)

    # -------------------------- Objective function -------------------------------
    def _obj_(model):
        return -model.V2GRevenue
    model.objective = Objective(rule=_obj_, sense=minimize)

    #--------------------------- Run Optimization --------------------------------- 
    instance = model.create_instance()
    solver = SolverFactory('gurobi')
    #solver.options['MIPGap'] = 0.05
    results = solver.solve(instance, tee=False)
    #print(results)

    #----------------- Collect power solutions ---------------------- 
    ev_sol = np.zeros(n_time)

    for t in instance.T:
        ev_sol[t] = instance.cs_pow[t].value
    
    return ev_sol, instance.V2GRevenue.value

# %% [markdown]
# # Iterative Algorithm

# %%
EV_SOL_Itr = [np.zeros([n_cs,n_time])]
Gen_Cost_Itr, CO2_Cost_Itr, NCI_Itr, V2G_Prof_Itr = [], [], [], []

for r in range(100):
    
    ev_sol = EV_SOL_Itr[-1]
    
    for k in range(n_cs):
    
        # stage 1: national grid
        dg_sol, res_sol, flow_sol, gen_cost, co2_cost = national_grid(ev_sol)
        Gen_Cost_Itr.append(gen_cost)
        CO2_Cost_Itr.append(co2_cost)

        # ev discharge
        ev_discharge = np.zeros([n_cs,n_time])    
        for k in range(n_cs):
            for t in range(n_time):
                if ev_sol[k,t] <= 0:
                    ev_discharge[k,t] = ev_sol[k,t]

        # cef
        Bus_CI = []
        for t in range(n_time):
            e_CEFT_time = calculate_carbon_intensity(t, dg_sol, res_sol, ev_discharge, flow_sol)
            Bus_CI.append(e_CEFT_time)
        Bus_CI = np.array(Bus_CI)
        NCI_Itr.append(Bus_CI)

        print('##### Iteration:', r, ', CS:', k, ', Carbon Cost:', co2_cost, ', CI:', np.mean(Bus_CI), ' #####')

        # stage 2: local ev
        ev_sol_k, v2g_profit_k = v2g_response(k, Bus_CI)
        ev_sol[k] = ev_sol_k
        V2G_Prof_Itr.append(v2g_profit)

        print('##### Iteration:', r, ', CS:', k, ', EV Profit:', v2g_profit, ' #####')
        
    EV_SOL_Itr.append(ev_sol)
    print('')
# Out:
# ########### Iteration: 0 , National Grid Done , Carbon Cost: 9691856.279974798 , CI: 126.18912781135536  ###########
# ########### Iteration: 0 , V2G Response Done , EV Profit: 401.1944261473925  ###########
#
# ########### Iteration: 1 , National Grid Done , Carbon Cost: 9203216.500287648 , CI: 116.5423562277725  ###########
# ########### Iteration: 1 , V2G Response Done , EV Profit: 344.0882069226768  ###########
#
# ########### Iteration: 2 , National Grid Done , Carbon Cost: 9348504.965603642 , CI: 114.19685113087868  ###########
# ########### Iteration: 2 , V2G Response Done , EV Profit: 603.8404729996181  ###########
#
# ########### Iteration: 3 , National Grid Done , Carbon Cost: 9298480.900065923 , CI: 114.04548705547897  ###########
# ########### Iteration: 3 , V2G Response Done , EV Profit: 529.1273579421442  ###########
#
# ########### Iteration: 4 , National Grid Done , Carbon Cost: 9496052.49796854 , CI: 114.45672832356091  ###########
# ########### Iteration: 4 , V2G Response Done , EV Profit: 742.0798997815174  ###########
#
# ########### Iteration: 5 , National Grid Done , Carbon Cost: 9408035.897220943 , CI: 114.20392514387657  ###########
# ########### Iteration: 5 , V2G Response Done , EV Profit: 626.6830018920051  ###########
#
# ########### Iteration: 6 , National Grid Done , Carbon Cost: 9526661.68221366 , CI: 114.12942956226618  ###########
# ########### Iteration: 6 , V2G Response Done , EV Profit: 782.704583885532  ###########
#
# ########### Iteration: 7 , National Grid Done , Carbon Cost: 9447508.245800039 , CI: 114.12388561187527  ###########
# ########### Iteration: 7 , V2G Response Done , EV Profit: 659.3078067456859  ###########
#
# ########### Iteration: 8 , National Grid Done , Carbon Cost: 9538415.373184457 , CI: 114.18934354220664  ###########
# ########### Iteration: 8 , V2G Response Done , EV Profit: 797.1270161474914  ###########
#
# ########### Iteration: 9 , National Grid Done , Carbon Cost: 9456365.276839893 , CI: 114.05694446965079  ###########
# ########### Iteration: 9 , V2G Response Done , EV Profit: 680.2296712243552  ###########
#
# ########### Iteration: 10 , National Grid Done , Carbon Cost: 9554562.630156787 , CI: 114.04998083383816  ###########
# ########### Iteration: 10 , V2G Response Done , EV Profit: 803.0711719596973  ###########
#
# ########### Iteration: 11 , National Grid Done , Carbon Cost: 9492221.238806346 , CI: 113.81119269463572  ###########
# ########### Iteration: 11 , V2G Response Done , EV Profit: 711.1155611743018  ###########
#
# ########### Iteration: 12 , National Grid Done , Carbon Cost: 9557630.3749146 , CI: 113.95682339760576  ###########
# ########### Iteration: 12 , V2G Response Done , EV Profit: 812.2992788566943  ###########
#
# ########### Iteration: 13 , National Grid Done , Carbon Cost: 9512108.365261778 , CI: 113.86195265509862  ###########
# ########### Iteration: 13 , V2G Response Done , EV Profit: 710.9583046222721  ###########
#
# ########### Iteration: 14 , National Grid Done , Carbon Cost: 9556583.180793453 , CI: 113.97012066018657  ###########
# ########### Iteration: 14 , V2G Response Done , EV Profit: 809.4423131360924  ###########
#
# ########### Iteration: 15 , National Grid Done , Carbon Cost: 9513702.059964012 , CI: 114.00668857828398  ###########
# ########### Iteration: 15 , V2G Response Done , EV Profit: 715.4177980386809  ###########
#
# ########### Iteration: 16 , National Grid Done , Carbon Cost: 9556536.615177393 , CI: 113.87755394242495  ###########
# ########### Iteration: 16 , V2G Response Done , EV Profit: 812.3759360747865  ###########
#
# ########### Iteration: 17 , National Grid Done , Carbon Cost: 9511625.274682904 , CI: 113.90523741721522  ###########
# ########### Iteration: 17 , V2G Response Done , EV Profit: 710.2254933484984  ###########
#
# ########### Iteration: 18 , National Grid Done , Carbon Cost: 9557028.817501212 , CI: 113.99400110249147  ###########
# ########### Iteration: 18 , V2G Response Done , EV Profit: 807.3845910294401  ###########
#
# ########### Iteration: 19 , National Grid Done , Carbon Cost: 9514137.136391835 , CI: 114.01729112610734  ###########
# ########### Iteration: 19 , V2G Response Done , EV Profit: 715.6758877741954  ###########
#
# ########### Iteration: 20 , National Grid Done , Carbon Cost: 9555909.666172773 , CI: 113.87931500997877  ###########
# ########### Iteration: 20 , V2G Response Done , EV Profit: 811.865897089784  ###########
#
# ########### Iteration: 21 , National Grid Done , Carbon Cost: 9512530.791075502 , CI: 113.91466124084482  ###########
# ########### Iteration: 21 , V2G Response Done , EV Profit: 710.576194793635  ###########
#
# ########### Iteration: 22 , National Grid Done , Carbon Cost: 9557216.875624944 , CI: 114.00069697697576  ###########
# ########### Iteration: 22 , V2G Response Done , EV Profit: 807.4189950208095  ###########
#
# ########### Iteration: 23 , National Grid Done , Carbon Cost: 9514510.542935926 , CI: 114.02473937818985  ###########
# ########### Iteration: 23 , V2G Response Done , EV Profit: 715.7124551264943  ###########
#
# ########### Iteration: 24 , National Grid Done , Carbon Cost: 9555518.067531561 , CI: 113.87654240149152  ###########
# ########### Iteration: 24 , V2G Response Done , EV Profit: 811.7171365828247  ###########
#
# ########### Iteration: 25 , National Grid Done , Carbon Cost: 9512370.476614451 , CI: 113.92386051632415  ###########
# ########### Iteration: 25 , V2G Response Done , EV Profit: 710.4083941939543  ###########
#
# ########### Iteration: 26 , National Grid Done , Carbon Cost: 9556435.130523477 , CI: 113.99609035105182  ###########
# ########### Iteration: 26 , V2G Response Done , EV Profit: 807.2033964247992  ###########
#
# ########### Iteration: 27 , National Grid Done , Carbon Cost: 9514353.216439743 , CI: 114.04748224372031  ###########
# ########### Iteration: 27 , V2G Response Done , EV Profit: 715.5130455923761  ###########
#
# ########### Iteration: 28 , National Grid Done , Carbon Cost: 9555371.522540973 , CI: 113.87764371870249  ###########
# ########### Iteration: 28 , V2G Response Done , EV Profit: 812.0332204238538  ###########
#
# ########### Iteration: 29 , National Grid Done , Carbon Cost: 9512353.997643255 , CI: 113.93157669034385  ###########
# ########### Iteration: 29 , V2G Response Done , EV Profit: 710.1248712673923  ###########
#
# ########### Iteration: 30 , National Grid Done , Carbon Cost: 9554607.861780575 , CI: 113.98874797924509  ###########
# ########### Iteration: 30 , V2G Response Done , EV Profit: 807.4065940662077  ###########
#
# ########### Iteration: 31 , National Grid Done , Carbon Cost: 9514350.25129266 , CI: 114.053190731573  ###########
# ########### Iteration: 31 , V2G Response Done , EV Profit: 715.4382540751875  ###########
#
# ########### Iteration: 32 , National Grid Done , Carbon Cost: 9555371.522540973 , CI: 113.87764371870249  ###########
# ########### Iteration: 32 , V2G Response Done , EV Profit: 812.0332204238538  ###########
#
# ########### Iteration: 33 , National Grid Done , Carbon Cost: 9512353.997643255 , CI: 113.93157669034385  ###########
# ########### Iteration: 33 , V2G Response Done , EV Profit: 710.1248712673923  ###########
#
# ########### Iteration: 34 , National Grid Done , Carbon Cost: 9554607.861780575 , CI: 113.98874797924509  ###########
# ########### Iteration: 34 , V2G Response Done , EV Profit: 807.4065940662077  ###########
#
# ########### Iteration: 35 , National Grid Done , Carbon Cost: 9514350.25129266 , CI: 114.053190731573  ###########
# ########### Iteration: 35 , V2G Response Done , EV Profit: 715.4382540751875  ###########
#
# ########### Iteration: 36 , National Grid Done , Carbon Cost: 9555371.522540973 , CI: 113.87764371870249  ###########
# ########### Iteration: 36 , V2G Response Done , EV Profit: 812.0332204238538  ###########
#
# ########### Iteration: 37 , National Grid Done , Carbon Cost: 9512353.997643255 , CI: 113.93157669034385  ###########
# ########### Iteration: 37 , V2G Response Done , EV Profit: 710.1248712673923  ###########
#
# ########### Iteration: 38 , National Grid Done , Carbon Cost: 9554607.861780575 , CI: 113.98874797924509  ###########
# ########### Iteration: 38 , V2G Response Done , EV Profit: 807.4065940662077  ###########
#
# ########### Iteration: 39 , National Grid Done , Carbon Cost: 9514350.25129266 , CI: 114.053190731573  ###########
# ########### Iteration: 39 , V2G Response Done , EV Profit: 715.4382540751875  ###########
#
# ########### Iteration: 40 , National Grid Done , Carbon Cost: 9555371.522540973 , CI: 113.87764371870249  ###########
# ########### Iteration: 40 , V2G Response Done , EV Profit: 812.0332204238538  ###########
#
# ########### Iteration: 41 , National Grid Done , Carbon Cost: 9512353.997643255 , CI: 113.93157669034385  ###########
# ########### Iteration: 41 , V2G Response Done , EV Profit: 710.1248712673923  ###########
#
# ########### Iteration: 42 , National Grid Done , Carbon Cost: 9554607.861780575 , CI: 113.98874797924509  ###########
# ########### Iteration: 42 , V2G Response Done , EV Profit: 807.4065940662077  ###########
#
# ########### Iteration: 43 , National Grid Done , Carbon Cost: 9514350.25129266 , CI: 114.053190731573  ###########
# ########### Iteration: 43 , V2G Response Done , EV Profit: 715.4382540751875  ###########
#
# ########### Iteration: 44 , National Grid Done , Carbon Cost: 9555371.522540973 , CI: 113.87764371870249  ###########
# ########### Iteration: 44 , V2G Response Done , EV Profit: 812.0332204238538  ###########
#
# ########### Iteration: 45 , National Grid Done , Carbon Cost: 9512353.997643255 , CI: 113.93157669034385  ###########
# ########### Iteration: 45 , V2G Response Done , EV Profit: 710.1248712673923  ###########
#
# ########### Iteration: 46 , National Grid Done , Carbon Cost: 9554607.861780575 , CI: 113.98874797924509  ###########
# ########### Iteration: 46 , V2G Response Done , EV Profit: 807.4065940662077  ###########
#
# ########### Iteration: 47 , National Grid Done , Carbon Cost: 9514350.25129266 , CI: 114.053190731573  ###########
# ########### Iteration: 47 , V2G Response Done , EV Profit: 715.4382540751875  ###########
#
# ########### Iteration: 48 , National Grid Done , Carbon Cost: 9555371.522540973 , CI: 113.87764371870249  ###########
# ########### Iteration: 48 , V2G Response Done , EV Profit: 812.0332204238538  ###########
#
# ########### Iteration: 49 , National Grid Done , Carbon Cost: 9512353.997643255 , CI: 113.93157669034385  ###########
# ########### Iteration: 49 , V2G Response Done , EV Profit: 710.1248712673923  ###########
#
# ########### Iteration: 50 , National Grid Done , Carbon Cost: 9554607.861780575 , CI: 113.98874797924509  ###########
# ########### Iteration: 50 , V2G Response Done , EV Profit: 807.4065940662077  ###########
#
# ########### Iteration: 51 , National Grid Done , Carbon Cost: 9514350.25129266 , CI: 114.053190731573  ###########
# ########### Iteration: 51 , V2G Response Done , EV Profit: 715.4382540751875  ###########
#
# ########### Iteration: 52 , National Grid Done , Carbon Cost: 9555371.522540973 , CI: 113.87764371870249  ###########
# ########### Iteration: 52 , V2G Response Done , EV Profit: 812.0332204238538  ###########
#
# ########### Iteration: 53 , National Grid Done , Carbon Cost: 9512353.997643255 , CI: 113.93157669034385  ###########
# ########### Iteration: 53 , V2G Response Done , EV Profit: 710.1248712673923  ###########
#
# ########### Iteration: 54 , National Grid Done , Carbon Cost: 9554607.861780575 , CI: 113.98874797924509  ###########
# ########### Iteration: 54 , V2G Response Done , EV Profit: 807.4065940662077  ###########
#
# ########### Iteration: 55 , National Grid Done , Carbon Cost: 9514350.25129266 , CI: 114.053190731573  ###########
# ########### Iteration: 55 , V2G Response Done , EV Profit: 715.4382540751875  ###########
#
# ########### Iteration: 56 , National Grid Done , Carbon Cost: 9555371.522540973 , CI: 113.87764371870249  ###########
# ########### Iteration: 56 , V2G Response Done , EV Profit: 812.0332204238538  ###########
#
# ########### Iteration: 57 , National Grid Done , Carbon Cost: 9512353.997643255 , CI: 113.93157669034385  ###########
# ########### Iteration: 57 , V2G Response Done , EV Profit: 710.1248712673923  ###########
#
# ########### Iteration: 58 , National Grid Done , Carbon Cost: 9554607.861780575 , CI: 113.98874797924509  ###########
# ########### Iteration: 58 , V2G Response Done , EV Profit: 807.4065940662077  ###########
#
# ########### Iteration: 59 , National Grid Done , Carbon Cost: 9514350.25129266 , CI: 114.053190731573  ###########
# ########### Iteration: 59 , V2G Response Done , EV Profit: 715.4382540751875  ###########
#
# ########### Iteration: 60 , National Grid Done , Carbon Cost: 9555371.522540973 , CI: 113.87764371870249  ###########
# ########### Iteration: 60 , V2G Response Done , EV Profit: 812.0332204238538  ###########
#
# ########### Iteration: 61 , National Grid Done , Carbon Cost: 9512353.997643255 , CI: 113.93157669034385  ###########
# ########### Iteration: 61 , V2G Response Done , EV Profit: 710.1248712673923  ###########
#
# ########### Iteration: 62 , National Grid Done , Carbon Cost: 9554607.861780575 , CI: 113.98874797924509  ###########
# ########### Iteration: 62 , V2G Response Done , EV Profit: 807.4065940662077  ###########
#
# ########### Iteration: 63 , National Grid Done , Carbon Cost: 9514350.25129266 , CI: 114.053190731573  ###########
# ########### Iteration: 63 , V2G Response Done , EV Profit: 715.4382540751875  ###########
#
# ########### Iteration: 64 , National Grid Done , Carbon Cost: 9555371.522540973 , CI: 113.87764371870249  ###########
# ########### Iteration: 64 , V2G Response Done , EV Profit: 812.0332204238538  ###########
#
# ########### Iteration: 65 , National Grid Done , Carbon Cost: 9512353.997643255 , CI: 113.93157669034385  ###########
# ########### Iteration: 65 , V2G Response Done , EV Profit: 710.1248712673923  ###########
#
# ########### Iteration: 66 , National Grid Done , Carbon Cost: 9554607.861780575 , CI: 113.98874797924509  ###########
# ########### Iteration: 66 , V2G Response Done , EV Profit: 807.4065940662077  ###########
#
# ########### Iteration: 67 , National Grid Done , Carbon Cost: 9514350.25129266 , CI: 114.053190731573  ###########
# ########### Iteration: 67 , V2G Response Done , EV Profit: 715.4382540751875  ###########
#
# ########### Iteration: 68 , National Grid Done , Carbon Cost: 9555371.522540973 , CI: 113.87764371870249  ###########

# %% [markdown]
# # Carbon Intensity

# %%
fig = plt.figure(figsize=(5,2))
grid = plt.GridSpec(1, 1, wspace=0.0, hspace=0.0)
text1 = 10
text2 = 12
font1 = {'family': 'Times New Roman', 'weight': 'normal', 'size': text1}
font2 = {'family': 'Times New Roman', 'weight': 'normal', 'size': text2}
cmap = plt.get_cmap('coolwarm')

ax = fig.add_subplot()
cmap = ax.imshow(Bus_CI.T, cmap, interpolation='nearest', aspect='auto')
plt.tick_params(labelsize = text2)
plt.xticks(np.linspace(0,47,11), fontname = "Times New Roman")
plt.xticks([0,5,11,17,23,29,35,41,47],['0:00','3:00','6:00','9:00','12:00','15:00','18:00','21:00','24:00'])
plt.yticks(np.linspace(0,13,7), fontname = "Times New Roman")
plt.yticks([0,2,4,6,8,10,12],[1,3,5,7,9,11,13])
ax.set_xlim (0,47)
ax.set_ylim (0,13)
ax.set_xlabel('Time', font2)
ax.set_ylabel('Node', font2)
ax.set_title('(a) unmanaged', font2)

cax = fig.add_axes([0.93,0.12,0.02,0.78])
cb = fig.colorbar(cmap, cax=cax, orientation='vertical', label='Carbon intensity (gCO2/kWh)')
cb.set_label('CI (gCO2/kWh)', fontdict=font1)
cb.ax.tick_params(labelsize=text1)
#cb.set_ticks(np.linspace(0,400,5))
#cb.set_ticklabels(['0','100','200','300','400'], fontname = 'Times New Roman')

print(Bus_CI.shape)
plt.show()

# %% [markdown]
# # V2G Response

# %%
ev_charge = np.zeros([n_cs,n_time])
ev_discharge = np.zeros([n_cs,n_time])    
for k in range(n_cs):
    for t in range(n_time):
        if ev_sol[k,t] >= 0:
            ev_charge[k,t] = ev_sol[k,t]
        else:
            ev_discharge[k,t] = ev_sol[k,t]
ev_charge_sol = np.sum(ev_charge, axis=0)
ev_discharge_sol = np.sum(ev_discharge, axis=0)

plt.figure(figsize = (5,2))
sources = ['Charge','discharge']
colors = ['tab:olive', 'cyan']
x = range(48)
space = 0.3
text1 = 10
text2 = 12
font1 = {'family': 'Times New Roman', 'weight': 'normal', 'size': text1}
font2 = {'family': 'Times New Roman', 'weight': 'normal', 'size': text2}
font3 = {'family': 'Times New Roman', 'weight': 'bold', 'size': text2}
stacks = plt.stackplot(x, ev_charge_sol, labels=sources[0], colors=colors[0])
stacks = plt.stackplot(x, ev_discharge_sol, labels=sources[1], colors=colors[1])
plt.grid(b=None, which='major', linestyle='--', axis='y')
plt.tick_params(labelsize = text2)
plt.xticks(np.linspace(0,47,11), fontname = "Times New Roman")
plt.xticks([0,5,11,17,23,29,35,41,47],['0:00','3:00','6:00','9:00','12:00','15:00','18:00','21:00','24:00'])
plt.yticks(np.linspace(-4000,4000,6), fontname = "Times New Roman")
plt.xlim([0,47])
plt.ylabel('Charge Power (MW)', font2)
plt.xlabel('Time', font2)
hatches = ['']
for stack, hatch in zip(stacks, hatches):
    stack.set_hatch(hatch)
legend = plt.legend(loc='upper left', prop=font1, labelspacing=space, framealpha=1, ncol=1, bbox_to_anchor=(1.0, 1.025))
plt.show()

# %% [markdown]
# # Power Flows

# %%
plt.figure(figsize=(6,3))
y = range(n_line)
x = range(n_time)
text1 = 13
font1 = {'family': 'Times New Roman', 'weight': 'normal', 'size': text1}
for l in y:
    plt.plot(x, flow_sol[l], linewidth=1, label=l)
plt.tick_params(labelsize = text1)
plt.xlim(0,47)
plt.xticks(np.linspace(0,47,11), fontname = "Times New Roman")
plt.xticks([0,5,11,17,23,29,35,41,47],[1,6,12,18,24,30,36,42,48])
plt.yticks(np.linspace(-2000,4000,7), fontname = "Times New Roman")
plt.xlabel('Time (30min)', font1)
plt.ylabel("Power Flow (MW)", font1)
legend = plt.legend(loc='right', prop=font1, framealpha=1, ncol=4, bbox_to_anchor=(1.9, 0.5))
plt.show()

# %% [markdown]
# # Generation MIx

# %%
for t in instance.T:
    demand_sol[t] = sum(Dem_unit[d,t] for d in instance.Dem)
    
def deplicate_fun(x):
    return list(dict.fromkeys(x))
my_Gen_type = deplicate_fun(DG_type)
print(my_Gen_type)

Gen_Mix = np.zeros([len(my_Gen_type),n_time])
for gmix in range(len(my_Gen_type)):
    for g in range(n_dg):
        if my_Gen_type[gmix] == DG_type[g]:
            for t in range(n_time):
                Gen_Mix[gmix,t] += dg_sol[g,t]

for g in range(len(my_Gen_type)):
    print(my_Gen_type[g], sum(Gen_Mix[g,:]))
    
ev_charge = np.zeros([n_cs,n_time])
ev_discharge = np.zeros([n_cs,n_time])    
for k in range(n_cs):
    for t in range(n_time):
        if ev_sol[k,t] >= 0:
            ev_charge[k,t] = ev_sol[k,t]
        else:
            ev_discharge[k,t] = ev_sol[k,t]    
    
ev_charge_sol = np.sum(ev_charge, axis=0)
ev_discharge_sol = np.sum(ev_discharge, axis=0)
wind_sol = np.sum(res_sol[:8,:], axis=0)
solar_sol = np.sum(res_sol[-4:,:], axis=0)
ccgt_sol = Gen_Mix[0,:]
nuclear_sol = Gen_Mix[1,:]
chp_sol = Gen_Mix[2,:]
biomass_sol = Gen_Mix[3,:]
coal_sol = Gen_Mix[4,:]
ocgt_sol = Gen_Mix[5,:]
oil_sol = Gen_Mix[6,:]

print('EV Charge', np.sum(ev_charge_sol))
print('EV DisCharge', np.sum(ev_discharge_sol))
print('Wind', np.sum(wind_sol))
print('Solar', np.sum(solar_sol))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (5,2))
sources = ['Nuclear', 'Wind', 'Solar', 'Coal', 'CHP', 'Biomass', 'CCGT', 'OCGT', 'Oil', 'V2G']
colors = ['tab:gray','tab:blue','tab:green','tab:orange','tab:brown','tab:purple','tab:red','chocolate','tab:olive','cyan']
x = range(48)
line_width = 3
space = 0.3
text1 = 10
text2 = 12
font1 = {'family': 'Times New Roman', 'weight': 'normal', 'size': text1}
font2 = {'family': 'Times New Roman', 'weight': 'normal', 'size': text2}
plt.plot(x, demand_sol, '-', color='black', label='Demand', linewidth=line_width)
stacks = plt.stackplot(x, nuclear_sol, wind_sol, solar_sol, coal_sol, chp_sol, biomass_sol, ccgt_sol, ocgt_sol, oil_sol,
                       [-i for i in ev_discharge_sol],
                       labels=sources, colors=colors)
plt.grid(b=None, which='major', linestyle='--', axis='y')
plt.tick_params(labelsize = text2)
plt.xticks(np.linspace(0,47,11), fontname = "Times New Roman")
plt.xticks([0,5,11,17,23,29,35,41,47],['0:00','3:00','6:00','9:00','12:00','15:00','18:00','21:00','24:00'])
plt.yticks(np.linspace(0,35000,8), fontname = "Times New Roman")
plt.yticks([0,5000,10000,15000,20000,25000,30000,35000],[0,5,10,15,20,25,30,35])
plt.xlim([0,47])
plt.ylim([0,35000])
plt.ylabel('Power Supply (GW)', font2)
plt.xlabel('Time', font2)
plt.title('(a) centralised', font2)
hatches = ['','','','','','','','','','//']
for stack, hatch in zip(stacks, hatches):
    stack.set_hatch(hatch)
legend = plt.legend(loc='upper left', prop=font1, labelspacing=space, framealpha=1, ncol=1, bbox_to_anchor=(1.1, 1.2))

plt.show()

# %%
ccgt_tot, nuclear_tot, chp_tot, biomass_tot = sum(Gen_Mix[0,:]), sum(Gen_Mix[1,:]), sum(Gen_Mix[2,:]), sum(Gen_Mix[3,:])
coal_tot, ocgt_tot, oil_tot = sum(Gen_Mix[4,:]), sum(Gen_Mix[5,:]), sum(Gen_Mix[6,:])
wind_tot, solar_tot = np.sum(wind_sol), np.sum(solar_sol)
v2g_tot = -np.sum(ev_discharge_sol)

data = {'ccgt':ccgt_tot, 'chp':chp_tot, 
        'nuclear':nuclear_tot, 'biomass':biomass_tot, 'wind':wind_tot, 'solar':solar_tot, 'v2g':v2g_tot}
colors = ['tab:red','tab:brown','tab:gray','tab:purple','tab:blue','tab:green','cyan'] 

base_d = sum(list(data.values()))
final_data = {k:m/base_d*100 for k,m in data.items()}

fig, ax = plt.subplots(figsize=(7,3.5), subplot_kw=dict(aspect="equal"))
size = 0.3
text1 = 10
text2 = 12
font1 = {'family': 'Times New Roman', 'weight': 'normal', 'size': text1}
font2 = {'family': 'Times New Roman', 'weight': 'normal', 'size': text2}
recipe = list(final_data.keys())
data = list(final_data.values())
perc = [str(int(round(e / s * 100, 0))) + '%' for s in (sum(data),) for e in data]
wedges, texts = ax.pie(data, wedgeprops=dict(width=size), colors=colors)
kw = dict(arrowprops=dict(arrowstyle='-'), zorder=0, va='center')

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2 + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i] + ' ' + perc[i], 
                xy=(x, y), 
                xytext=(1.1*np.sign(x), 1.1*y), 
                fontsize=text1,
                color=colors[i],
                horizontalalignment=horizontalalignment, 
                **kw)

data0 = [[coal_tot, oil_tot, ocgt_tot, ccgt_tot, chp_tot], [nuclear_tot, biomass_tot, wind_tot, solar_tot,v2g_tot]]
class0 = ['fossil', 'res']
color0 = ['chocolate', 'deepskyblue']
sums = [sum(i) for i in data0]
plt.pie(sums, radius=1-size, colors=color0, wedgeprops=dict(width=size, edgecolor='w'), autopct='%1.0f%%', pctdistance=0.75)
plt.text(0.372, 0.692, class0[0], color='black', fontsize=text1, transform=ax.transAxes)
plt.text(0.352, 0.284, class0[1], color='black', fontsize=text1, transform=ax.transAxes)

plt.text(0.46, 0.53, '218', weight='bold', color='red', fontsize=text2, transform=ax.transAxes)
plt.text(0.35, 0.47, 'gCO2/kWh', weight='bold', color='red', fontsize=text2, transform=ax.transAxes)
ax.set_title('(b) centralised', font2)

plt.show()

# %% [markdown]
# # Carbon Intensity

# %%
Gen_Bus = np.concatenate((DG_bus, RES_bus, CS_bus), axis=0)
Gen_Day = np.vstack((dg_sol, res_sol, -ev_discharge)).T
RES_Carbon = np.zeros(n_res)
EV_Carbon = np.zeros(n_cs)
Gen_CF = np.concatenate((DG_Carbon, RES_Carbon, EV_Carbon), axis=0)

def calculate_carbon_intensity(time):
    # define terms
    P_CEFG = np.zeros([n_bus, n_dg+n_res+n_cs])
    e_CEFG = Gen_CF
    P_B = np.zeros([n_bus, n_bus])
    
    # calculate power generation for each bus
    Gen_t = Gen_Day[time]
    for b in range(n_bus):
        for g in range(len(Gen_Bus)):
            if b == Gen_Bus[g]:
                P_CEFG[b,g] = Gen_t[g]
            
    # calculate power flow
    for l in range(n_line):
        b = Line_top[l,0]
        p = Line_top[l,1]
        if flow_sol[l,time] >= 0:
            P_B[b,p] = flow_sol[l,time]
        else:
            P_B[p,b] = - flow_sol[l,time]
            
    # calculate carbon emission rates of power genenration
    r_CEFG = P_CEFG.dot(e_CEFG)
    
    # calculate the distribution of power inflows from both other buses and local generators 
    P_CEFT = np.diag( np.ones([1, n_bus+len(Gen_Bus)]).dot(np.vstack((P_B, P_CEFG.transpose())))[0] )
    
    # calculate bus carbon emission intensities
    e_CEFT = np.linalg.pinv(P_CEFT - P_B.transpose()).dot(r_CEFG)
    
    return e_CEFT

# %%
Bus_CI = []
for t in range(n_time):
    e_CEFT_time = calculate_carbon_intensity(t)
    Bus_CI.append(e_CEFT_time)
Bus_CI = np.array(Bus_CI)
print(Bus_CI.shape)
print('Max:', np.max(Bus_CI))
print('Min:', np.min(Bus_CI))
print('Sum:', np.sum(Bus_CI))
print('Averaged:', np.sum(Bus_CI)/(n_time*n_bus))

# %%
fig = plt.figure(figsize=(5,2))
grid = plt.GridSpec(1, 1, wspace=0.0, hspace=0.0)
text1 = 10
text2 = 12
font1 = {'family': 'Times New Roman', 'weight': 'normal', 'size': text1}
font2 = {'family': 'Times New Roman', 'weight': 'normal', 'size': text2}
cmap = plt.get_cmap('coolwarm')

ax = fig.add_subplot()
cmap = ax.imshow(Bus_CI.T, cmap, interpolation='nearest', aspect='auto')
plt.tick_params(labelsize = text2)
plt.xticks(np.linspace(0,47,11), fontname = "Times New Roman")
plt.xticks([0,5,11,17,23,29,35,41,47],['0:00','3:00','6:00','9:00','12:00','15:00','18:00','21:00','24:00'])
plt.yticks(np.linspace(0,13,7), fontname = "Times New Roman")
plt.yticks([0,2,4,6,8,10,12],[1,3,5,7,9,11,13])
ax.set_xlim (0,47)
ax.set_ylim (0,13)
ax.set_xlabel('Time', font2)
ax.set_ylabel('Node', font2)
ax.set_title('(a) centralised', font2)

cax = fig.add_axes([0.93,0.12,0.02,0.78])
cb = fig.colorbar(cmap, cax=cax, orientation='vertical', label='Carbon intensity (gCO2/kWh)')
cb.set_label('CI (gCO2/kWh)', fontdict=font1)
cb.ax.tick_params(labelsize=text1)
#cb.set_ticks(np.linspace(0,400,5))
#cb.set_ticklabels(['0','100','200','300','400'], fontname = 'Times New Roman')

plt.show()

# %% [markdown]
# # To Excel

# %%
dispatch_sol = np.array([nuclear_sol, wind_sol, solar_sol, chp_sol, biomass_sol, ccgt_sol,
                         [-i for i in ev_discharge_sol]])
genmix_sol = np.array([ccgt_tot, chp_tot, nuclear_tot, biomass_tot, wind_tot, solar_tot, v2g_tot])
ev_sol = np.array([ev_charge_sol, ev_discharge_sol])
excel_dispatch_data = pd.DataFrame(dispatch_sol)
excel_genmix_data = pd.DataFrame(genmix_sol)
excel_ev_data = pd.DataFrame(ev_sol)
excel_ci_data = pd.DataFrame(Bus_CI.T)

# %%
with pd.ExcelWriter('result_proposed.xlsx') as writer:
    excel_dispatch_data.to_excel(writer, sheet_name='dispatch', index=False)
    excel_genmix_data.to_excel(writer, sheet_name='genmix', index=False)
    excel_ev_data.to_excel(writer, sheet_name='ev', index=False)
    excel_ci_data.to_excel(writer, sheet_name="carbon", index=False)
